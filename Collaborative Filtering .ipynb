# %% [markdown]
# ## AUDIO CONTENT BASED ANALYSIS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install essentia
# !pip install essentia-tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting essentia
#   Downloading essentia-2.1b6.dev858-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 44.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from essentia) (6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from essentia) (1.15.0)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.8/dist-packages (from essentia) (1.22.4)
# Installing collected packages: essentia
# Successfully installed essentia-2.1b6.dev858
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting essentia-tensorflow
#   Downloading essentia_tensorflow-2.1b6.dev858-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (291.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.4/291.4 MB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from essentia-tensorflow) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from essentia-tensorflow) (6.0)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.8/dist-packages (from essentia-tensorflow) (1.22.4)
# Installing collected packages: essentia-tensorflow
# Successfully installed essentia-tensorflow-2.1b6.dev858

# %% [markdown]
# ## Loop for features extraction.

# %%
import csv
from tqdm import tqdm
import numpy as np
import json
import os
from essentia.standard import  MonoLoader, RhythmExtractor2013, TensorflowPredictEffnetDiscogs, TensorflowPredictMusiCNN, TensorflowPredict2D
import pandas as pd

def find_audio_files(path):
    audio_files = []

    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith(('.wav', '.mp3', '.flac', '.aac')):
                audio_files.append(os.path.join(root, file))
    print('Audio files extracted',audio_files)
    print('Dataset size:',len(audio_files))
    return audio_files

path = "/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks"
audio_files = find_audio_files(path)

with open("/content/drive/MyDrive/Colab_Notebooks/AMPLAB/styles.txt", "r") as file:
    # Read the contents of the file and split the lines into a list of strings
    styles = file.read().splitlines()


def load_audio_file(path):
  return MonoLoader(filename=path)()

def bpm_calculation(audio):
  bpm,_,confidence,_,_=RhythmExtractor2013()(audio)

  return bpm,confidence
  
def music_style(audio,styles):
  model = TensorflowPredictEffnetDiscogs(graphFilename="/content/drive/MyDrive/Colab_Notebooks/AMPLAB/discogs-effnet-bs64-1.pb")
  activations = model(audio)
  activations = np.mean(activations, axis=0)
  predominant_index = np.argmax(activations)
  predominant=styles[predominant_index]
  
  return activations,predominant

def voice_instrumental(audio):
  model= TensorflowPredictMusiCNN(graphFilename="/content/drive/MyDrive/Colab_Notebooks/AMPLAB/voice_instrumental-musicnn-msd-2.pb")
  activations = model(audio)
  activations = np.mean(activations, axis=0)
  instrumental = activations[0]
  voice = activations [1]
  
  return instrumental, voice

def danceabilities(audio):
  model= TensorflowPredictMusiCNN(graphFilename='/content/drive/MyDrive/Colab_Notebooks/AMPLAB/danceability-musicnn-msd-2.pb')
  activations = model(audio)
  activations = np.mean(activations, axis=0)
  danceable = activations[0]
  
  return danceable

def arousal_valence(audio):
  embeddings_model = TensorflowPredictMusiCNN(graphFilename="/content/drive/MyDrive/Colab_Notebooks/AMPLAB/msd-musicnn-1.pb",output="model/dense/BiasAdd")
  model=TensorflowPredict2D(graphFilename='/content/drive/MyDrive/Colab_Notebooks/AMPLAB/emomusic-musicnn-msd-2.pb',output="model/Identity")
  embeddings=embeddings_model(audio)
  activations = model(embeddings)
  activations = np.mean(activations, axis=0)
  arousal = activations[0]
  valence = activations[1]

  return arousal, valence

df = pd.DataFrame(columns=['audio_path', 'bpm', 'music_styles', 'voice', 'instrumental', 'danceability', 'arousal', 'valence', 'predominant music style'])

total_files= len(audio_files)
# Open the JSON file in append mode
with open('/content/drive/MyDrive/Colab_Notebooks/AMPLAB/features/features.csv', 'a') as f:
  writer = csv.writer(f)
  with tqdm(total=total_files, desc='Processing audio files') as pbar:
    for i, audio_path in tqdm(enumerate(audio_files, 0)):
      audio = load_audio_file(audio_path)

      bpm, confidence = bpm_calculation(audio)
      music_styles, predominant = music_style(audio,styles)
      instrumental, voice  = voice_instrumental(audio)
      danceability = danceabilities(audio)
      arousal, valence = arousal_valence(audio)
     
      df.loc[len(df)] = [audio_path, bpm, music_styles, voice, instrumental, danceability, arousal, valence, predominant]
      df.to_csv('/content/drive/MyDrive/Colab_Notebooks/AMPLAB/features/features.csv', index=False)

      pbar.update(1)
      pbar.set_postfix({'progress': f'{pbar.n}/{total_files} ({pbar.n/total_files:.0%})'})
# Out:
# Audio files extracted ['/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/5Z/5Z54RgCfhRljLVjPZHy5dv.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/7G/7GgYmXY3PfDjTiyjUlvF7Y.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/0z/0zf1BQJ4om2qU0W9muvnLn.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/4s/4sCcDvX30uu39ozvxcRsqB.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/6Z/6ZBiXweylRlROqwP3ODYgw.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/4X/4XLVg8qERMwZBy0HHr2DdW.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/4X/4XQETu7QYGbUhTt68kekOn.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/4r/4rhaDfV9y5UvGZ67BT8U35.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/2D/2DOfw6UDf0eyCdb0SMVZrE.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/5f/5fz5MpkCMxmkwmnPCelvaK.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/4k/4kadqVh0yCzjpsbFvvtafG.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/7g/7g21lXTmZhNx4j2c7Ni6a4.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/3c/3cLVS99dde6vmoEnw395SS.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/6D/6Di0ZM5lts34FhpRhPwt28.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/4H/4Hzss8q0jDWa2PjXDGqYZL.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/4H/4HQSjQBUNpQxAU0s1OKJoL.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/6a/6ad10kjPhLwQgdfQRtkVhe.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/6a/6asQj4fkjQw92XUkoHiukh.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/77/77j9SlhRd4MBGU998c7dnw.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/6h/6hae4FKhe6GE6VPjo9avaB.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/41/41JLeAkwHqFQwmIHEqHc1a.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/3W/3WquUOQuUHIJc7l86FGA52.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/2t/2teSLnlDwFbAFza8rZihj0.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/35/35U4PXL3W3XIkAjEUdhr36.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/4p/4pIiKrGXCgTZOAFGJjCEvL.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/4p/4ptPiH5pwgLj2M2gFhu0uz.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/57/57a8sOc39lnCZzEmRWppce.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/57/57HvueguHroRluYYB4Nk26.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/6L/6LdKmpe4OMYKPBijgI9423.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/2E/2ERG0rdikiQy2858baYqV5.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/7r/7rkl4JNJFOSbrMrrT2KJjS.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/7r/7rVhW9T2OxhHTkMrjLf2w4.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/0P/0PJDYtpq8UIi2a3pCwOONd.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/5d/5dZDQPiC2PGom8Q8pEqKgW.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/2J/2Jok6fkKmcP7Lp7XLzQ1wj.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/3S/3ShMfVYb97EAhZ16HZzS25.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/3S/3SLHDuEf8RCAGHmdh5tr9u.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/31/31jC6KX8ESF4zw2vcXgiH1.mp3', '/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001/1q/1qYYruLP1FATpnZxPMHUut.mp3', ...
# Dataset size: 2100
# 1846it [3:11:41,  8.69s/it]

# %%
import csv
from tqdm import tqdm
import numpy as np
import json
import os
from essentia.standard import  MonoLoader, RhythmExtractor2013, TensorflowPredictEffnetDiscogs, TensorflowPredictMusiCNN, TensorflowPredict2D
import pandas as pd

def find_audio_files(path):
    audio_files = []

    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith(('.wav', '.mp3', '.flac', '.aac')):
                audio_files.append(os.path.join(root, file))
    print('Audio files extracted',audio_files)
    print('Dataset size:',len(audio_files))
    return audio_files

path = "/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks"
audio_files = find_audio_files(path)
audio_files = audio_files[1850:]
print('Length of audio files:',len(audio_files))

with open("/content/drive/MyDrive/Colab_Notebooks/AMPLAB/styles.txt", "r") as file:
    # Read the contents of the file and split the lines into a list of strings
    styles = file.read().splitlines()


def load_audio_file(path):
  return MonoLoader(filename=path)()

def bpm_calculation(audio):
  bpm,_,confidence,_,_=RhythmExtractor2013()(audio)

  return bpm,confidence
  
def music_style(audio,styles):
  model = TensorflowPredictEffnetDiscogs(graphFilename="/content/drive/MyDrive/Colab_Notebooks/AMPLAB/discogs-effnet-bs64-1.pb")
  activations = model(audio)
  activations = np.mean(activations, axis=0)
  predominant_index = np.argmax(activations)
  predominant=styles[predominant_index]
  
  return activations,predominant

def voice_instrumental(audio):
  model= TensorflowPredictMusiCNN(graphFilename="/content/drive/MyDrive/Colab_Notebooks/AMPLAB/voice_instrumental-musicnn-msd-2.pb")
  activations = model(audio)
  activations = np.mean(activations, axis=0)
  instrumental = activations[0]
  voice = activations [1]
  
  return instrumental, voice

def danceabilities(audio):
  model= TensorflowPredictMusiCNN(graphFilename='/content/drive/MyDrive/Colab_Notebooks/AMPLAB/danceability-musicnn-msd-2.pb')
  activations = model(audio)
  activations = np.mean(activations, axis=0)
  danceable = activations[0]
  
  return danceable

def arousal_valence(audio):
  embeddings_model = TensorflowPredictMusiCNN(graphFilename="/content/drive/MyDrive/Colab_Notebooks/AMPLAB/msd-musicnn-1.pb",output="model/dense/BiasAdd")
  model=TensorflowPredict2D(graphFilename='/content/drive/MyDrive/Colab_Notebooks/AMPLAB/emomusic-musicnn-msd-2.pb',output="model/Identity")
  embeddings=embeddings_model(audio)
  activations = model(embeddings)
  activations = np.mean(activations, axis=0)
  arousal = activations[0]
  valence = activations[1]

  return arousal, valence

df = pd.DataFrame(columns=['audio_path', 'bpm', 'music_styles', 'voice', 'instrumental', 'danceability', 'arousal', 'valence', 'predominant music style'])

total_files= len(audio_files)

# Open the JSON file in append mode

with open('/content/drive/MyDrive/Colab_Notebooks/AMPLAB/features/features2.csv', 'a') as f:
  writer = csv.writer(f)
  with tqdm(total=total_files, desc='Processing audio files') as pbar:
    for audio_path in tqdm(audio_files):
      audio = load_audio_file(audio_path)

      bpm, confidence = bpm_calculation(audio)
      music_styles, predominant = music_style(audio,styles)
      instrumental, voice  = voice_instrumental(audio)
      danceability = danceabilities(audio)
      arousal, valence = arousal_valence(audio)
      
     
      df.loc[len(df)] = [audio_path, bpm, music_styles, voice, instrumental, danceability, arousal, valence, predominant]
      df.to_csv('/content/drive/MyDrive/Colab_Notebooks/AMPLAB/features/features2.csv', index=False)

      pbar.update(1)
      pbar.set_postfix({'progress': f'{pbar.n}/{total_files} ({pbar.n/total_files:.0%})'})
# Out:
# Audio files extracted ['/content/drive/MyDrive/Colab_Notebooks/AMPLAB/audio_chunks/audio.001
# Processing audio files:  75%|███████▌  | 188/250 [12:23<04:30,  4.36s/it, progress=188/250 (75%)]
# Processing audio files:  76%|███████▌  | 189/250 [12:27<04:14,  4.17s/it, progress=189/250 (76%)]
# Processing audio files:  76%|███████▌  | 190/250 [12:30<04:04,  4.07s/it, progress=190/250 (76%)]
# Processing audio files:  76%|███████▋  | 191/250 [12:35<04:11,  4.27s/it, progress=191/250 (76%)]
# Processing audio files:  77%|███████▋  | 192/250 [12:39<04:03,  4.20s/it, progress=192/250 (77%)]
# Processing audio files:  77%|███████▋  | 193/250 [12:43<03:51,  4.06s/it, progress=193/250 (77%)]
# Processing audio files:  78%|███████▊  | 194/250 [12:48<04:02,  4.32s/it, progress=194/250 (78%)]
# Processing audio files:  78%|███████▊  | 195/250 [12:52<03:48,  4.15s/it, progress=195/250 (78%)]
# Processing audio files:  78%|███████▊  | 196/250 [12:55<03:37,  4.03s/it, progress=196/250 (78%)]
# Processing audio files:  79%|███████▉  | 197/250 [13:00<03:46,  4.28s/it, progress=197/250 (79%)]
# Processing audio files:  79%|███████▉  | 198/250 [13:04<03:34,  4.13s/it, progress=198/250 (79%)]
# Processing audio files:  80%|███████▉  | 199/250 [13:08<03:27,  4.07s/it, progress=199/250 (80%)]
# Processing audio files:  80%|████████  | 200/250 [13:13<03:36,  4.32s/it, progress=200/250 (80%)]
# Processing audio files:  80%|████████  | 201/250 [13:17<03:24,  4.18s/it, progress=201/250 (80%)]
# Processing audio files:  81%|████████  | 202/250 [13:21<03:17,  4.12s/it, progress=202/250 (81%)]
# Processing audio files:  81%|████████  | 203/250 [13:25<03:20,  4.26s/it, progress=203/250 (81%)]
# Processing audio files:  82%|████████▏ | 204/250 [13:30<03:16,  4.27s/it, progress=204/250 (82%)]
# Processing audio files:  82%|████████▏ | 205/250 [13:33<03:06,  4.14s/it, progress=205/250 (82%)]
# Processing audio files:  82%|████████▏ | 206/250 [13:39<03:15,  4.45s/it, progress=206/250 (82%)]
# Processing audio files:  83%|████████▎ | 207/250 [13:43<03:08,  4.39s/it, progress=207/250 (83%)]
# Processing audio files:  83%|████████▎ | 208/250 [13:47<02:57,  4.23s/it, progress=208/250 (83%)]
# Processing audio files:  84%|████████▎ | 209/250 [13:52<03:02,  4.46s/it, progress=209/250 (84%)]
# Processing audio files:  84%|████████▍ | 210/250 [13:55<02:50,  4.26s/it, progress=210/250 (84%)]
# Processing audio files:  84%|████████▍ | 211/250 [13:59<02:41,  4.14s/it, progress=211/250 (84%)]
# Processing audio files:  85%|████████▍ | 212/250 [14:04<02:43,  4.29s/it, progress=212/250 (85%)]
# Processing audio files:  85%|████████▌ | 213/250 [14:08<02:34,  4.18s/it, progress=213/250 (85%)]
# Processing audio files:  86%|████████▌ | 214/250 [14:12<02:27,  4.10s/it, progress=214/250 (86%)]
# Processing audio files:  86%|████████▌ | 215/250 [14:17<02:32,  4.37s/it, progress=215/250 (86%)]
# Processing audio files:  86%|████████▋ | 216/250 [14:21<02:25,  4.28s/it, progress=216/250 (86%)]
# Processing audio files:  87%|████████▋ | 217/250 [14:25<02:16,  4.15s/it, progress=217/250 (87%)]
# Processing audio files:  87%|████████▋ | 218/250 [14:29<02:18,  4.32s/it, progress=218/250 (87%)]
# Processing audio files:  88%|████████▊ | 219/250 [14:34<02:12,  4.29s/it, progress=219/250 (88%)]
# Processing audio files:  88%|████████▊ | 220/250 [14:38<02:05,  4.19s/it, progress=220/250 (88%)]
# Processing audio files:  88%|████████▊ | 221/250 [14:42<02:06,  4.37s/it, progress=221/250 (88%)]
# Processing audio files:  89%|████████▉ | 222/250 [14:46<01:57,  4.21s/it, progress=222/250 (89%)]
# Processing audio files:  89%|████████▉ | 223/250 [14:50<01:53,  4.21s/it, progress=223/250 (89%)]
# Processing audio files:  90%|████████▉ | 224/250 [14:55<01:52,  4.33s/it, progress=224/250 (90%)]
# Processing audio files:  90%|█████████ | 225/250 [14:59<01:44,  4.17s/it, progress=225/250 (90%)]
# Processing audio files:  90%|█████████ | 226/250 [15:03<01:37,  4.08s/it, progress=226/250 (90%)]
# Processing audio files:  91%|█████████ | 227/250 [15:08<01:40,  4.38s/it, progress=227/250 (91%)]
# Processing audio files:  91%|█████████ | 228/250 [15:12<01:36,  4.37s/it, progress=228/250 (91%)]
# Processing audio files:  92%|█████████▏| 229/250 [15:16<01:28,  4.23s/it, progress=229/250 (92%)]
# Processing audio files:  92%|█████████▏| 230/250 [15:21<01:27,  4.36s/it, progress=230/250 (92%)]
# Processing audio files:  92%|█████████▏| 231/250 [15:25<01:19,  4.20s/it, progress=231/250 (92%)]
# Processing audio files:  93%|█████████▎| 232/250 [15:28<01:14,  4.11s/it, progress=232/250 (93%)]
# Processing audio files:  93%|█████████▎| 233/250 [15:33<01:14,  4.37s/it, progress=233/250 (93%)]
# Processing audio files:  94%|█████████▎| 234/250 [15:38<01:09,  4.35s/it, progress=234/250 (94%)]
# Processing audio files:  94%|█████████▍| 235/250 [15:42<01:04,  4.29s/it, progress=235/250 (94%)]
# Processing audio files:  94%|█████████▍| 236/250 [15:46<01:01,  4.39s/it, progress=236/250 (94%)]
# Processing audio files:  95%|█████████▍| 237/250 [15:50<00:55,  4.24s/it, progress=237/250 (95%)]
# Processing audio files:  95%|█████████▌| 238/250 [15:54<00:50,  4.21s/it, progress=238/250 (95%)]
# Processing audio files:  96%|█████████▌| 239/250 [15:59<00:47,  4.34s/it, progress=239/250 (96%)]
# Processing audio files:  96%|█████████▌| 240/250 [16:03<00:42,  4.21s/it, progress=240/250 (96%)]
# Processing audio files:  96%|█████████▋| 241/250 [16:08<00:38,  4.30s/it, progress=241/250 (96%)]
# Processing audio files:  97%|█████████▋| 242/250 [16:13<00:36,  4.51s/it, progress=242/250 (97%)]
# Processing audio files:  97%|█████████▋| 243/250 [16:17<00:31,  4.46s/it, progress=243/250 (97%)]
# Processing audio files:  98%|█████████▊| 244/250 [16:21<00:25,  4.29s/it, progress=244/250 (98%)]
# Processing audio files:  98%|█████████▊| 245/250 [16:26<00:22,  4.49s/it, progress=245/250 (98%)]
# Processing audio files:  98%|█████████▊| 246/250 [16:30<00:17,  4.40s/it, progress=246/250 (98%)]
# Processing audio files:  99%|█████████▉| 247/250 [16:34<00:12,  4.23s/it, progress=247/250 (99%)]
# Processing audio files:  99%|█████████▉| 248/250 [16:38<00:08,  4.34s/it, progress=248/250 (99%)]
# Processing audio files: 100%|█████████▉| 249/250 [16:43<00:04,  4.36s/it, progress=249/250 (100%)]
# Processing audio files: 100%|██████████| 250/250 [16:47<00:00,  4.22s/it, progress=250/250 (100%)]
# 100%|██████████| 250/250 [16:47<00:00,  4.03s/it]
# Processing audio files: 100%|██████████| 250/250 [16:47<00:00,  4.03s/it, progress=250/250 (100%)]

# %%
df
# Out:
#                                             audio_path         bpm  \
# 0    /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  135.438889
# 1    /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  146.197830
# 2    /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...   75.443779
# 3    /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  106.415306
# 4    /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  139.765930
# ..                                                 ...         ...
# 245  /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...   73.310852
# 246  /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  136.569183
# 247  /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  108.029228
# 248  /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  131.834244
# 249  /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  108.907753
#
#                                           music_styles     voice  \
# 0    [9.019404e-06, 0.00010508032, 0.00020468996, 0...  0.458111
# 1    [4.537728e-06, 4.8221067e-05, 0.00042826874, 0...  0.305626
# 2    [3.7539594e-06, 3.8993836e-05, 3.9785442e-05, ...  0.351090
# 3    [4.9772884e-06, 2.43401e-05, 7.097772e-05, 0.0...  0.494610
# 4    [6.6940797e-06, 2.4406314e-05, 4.0803196e-05, ...  0.310157
# ..                                                 ...       ...
# 245  [8.601876e-06, 1.1693893e-05, 2.6612512e-05, 6...  0.254572
# 246  [4.660627e-05, 6.681148e-05, 0.00012161084, 0....  0.226477
# 247  [3.8266026e-06, 2.9110623e-05, 2.6878745e-06, ...  0.201561
# 248  [2.620681e-05, 3.597975e-05, 0.0003085332, 0.0...  0.427077
# 249  [2.4884388e-08, 9.5765685e-08, 1.3675077e-07, ...  0.202406
#
#      instrumental  danceability   arousal   valence  \
# 0        0.263399      0.270036  3.478802  4.271688
# 1        0.359743      0.257943  3.675216  4.951470
# 2        0.334521      0.316073  3.422647  4.959703
# 3        0.202900      0.450870  3.394173  5.769993
# 4        0.348921      0.549900  3.051960  4.095187
# ..            ...           ...       ...       ...
# 245      0.389736      0.185603  3.290955  3.507015
# 246      0.417134      0.344109  3.054225  4.300512
# 247      0.451785      0.874785  3.000327  4.777125
# 248      0.332533      0.309887  3.728135  3.764989
# 249      0.417041      0.318886  2.910684  4.042559
#
#                    predominant music style
# 0                "Electronic---Vaporwave",
# 1        "Electronic---Power Electronics",
# 2                "Electronic---Vaporwave",
# 3             "Electronic---Experimental",
# 4               "Electronic---Industrial",
# ..                                     ...
# 245           "Electronic---Experimental",
# 246           "Electronic---Experimental",
# 247              "Electronic---Vaporwave",
# 248              "Electronic---Vaporwave",
# 249           "Electronic---Dark Ambient",
#
# [250 rows x 9 columns]

# %%
import csv

df1 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/AMPLAB/features/features.csv')

# Read the second CSV file into a DataFrame
df2 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/AMPLAB/features/features2.csv')

# Concatenate the two DataFrames vertically
#combined_df = pd.concat([df1, df2])

# Write the combined DataFrame to a CSV file
#combined_df.to_csv('/content/drive/MyDrive/Colab_Notebooks/AMPLAB/features/combined_features.csv', index=False)
      
df1=df1[:1850]

combined_df = pd.concat([df1, df2])
combined_df.to_csv('/content/drive/MyDrive/Colab_Notebooks/AMPLAB/features/features3.csv', index=False)

# %%
import pandas as pd
df3=pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/AMPLAB/features/features3.csv')
df3
# Out:
#                                              audio_path         bpm  \
# 0     /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  119.751747
# 1     /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  153.446625
# 2     /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...   93.742500
# 3     /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  108.424217
# 4     /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  165.349686
# ...                                                 ...         ...
# 2095  /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...   73.310852
# 2096  /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  136.569183
# 2097  /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  108.029228
# 2098  /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  131.834244
# 2099  /content/drive/MyDrive/Colab_Notebooks/AMPLAB/...  108.907753
#
#                                            music_styles     voice  \
# 0     [5.05927419e-05 7.00273304e-05 6.95807976e-04 ...  0.342443
# 1     [6.21643674e-04 3.02357425e-04 7.01925135e-04 ...  0.440760
# 2     [4.49582330e-05 1.41592987e-04 2.90555734e-04 ...  0.253248
# 3     [9.99165604e-06 4.22870653e-04 4.65890975e-04 ...  0.504235
# 4     [1.62254364e-05 1.80955947e-04 1.43213590e-04 ...  0.240522
# ...                                                 ...       ...
# 2095  [8.60187629e-06 1.16938927e-05 2.66125116e-05 ...  0.254572
# 2096  [4.66062702e-05 6.68114808e-05 1.21610843e-04 ...  0.226477
# 2097  [3.82660255e-06 2.91106226e-05 2.68787448e-06 ...  0.201561
# 2098  [2.62068097e-05 3.59797486e-05 3.08533199e-04 ...  0.427077
# 2099  [2.48843879e-08 9.57656852e-08 1.36750771e-07 ...  0.202406
#
#       instrumental  danceability   arousal   valence  \
# 0         0.332771      0.163486  3.340117  3.374879
# 1         0.287215      0.253267  3.489979  4.115166
# 2         0.389446      0.265566  3.702826  4.368959
# 3         0.243679      0.257150  3.040704  5.242821
# 4         0.441403      0.255030  3.896225  4.917584
# ...            ...           ...       ...       ...
# 2095      0.389736      0.185603  3.290955  3.507015
# 2096      0.417134      0.344109  3.054225  4.300512
# 2097      0.451785      0.874785  3.000327  4.777125
# 2098      0.332533      0.309887  3.728135  3.764989
# 2099      0.417041      0.318886  2.910684  4.042559
#
#                predominant music style
# 0         "Electronic---Experimental",
# 1         "Electronic---Experimental",
# 2         "Electronic---Experimental",
# 3         "Electronic---Experimental",
# 4            "Electronic---Vaporwave",
# ...                                ...
# 2095      "Electronic---Experimental",
# 2096      "Electronic---Experimental",
# 2097         "Electronic---Vaporwave",
# 2098         "Electronic---Vaporwave",
# 2099      "Electronic---Dark Ambient",
#
# [2100 rows x 9 columns]

# %%
music_styles_= df3['predominant music style']
#music_styles_ = music_styles_.apply(ast.literal_eval)
print(music_styles_)

m=music_styles_.tolist()
print(m)
# Out:
# 0           "Electronic---Experimental",
# 1           "Electronic---Experimental",
# 2           "Electronic---Experimental",
# 3           "Electronic---Experimental",
# 4              "Electronic---Vaporwave",
#                       ...
# 2095        "Electronic---Experimental",
# 2096        "Electronic---Experimental",
# 2097           "Electronic---Vaporwave",
# 2098           "Electronic---Vaporwave",
# 2099        "Electronic---Dark Ambient",
# Name: predominant music style, Length: 2100, dtype: object
# ['    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Industrial",', '    "Electronic---Vaporwave",', '    "Non-Music---Spoken Word",', '    "Electronic---Vaporwave",', '    "Electronic---Dark Ambient",', '    "Electronic---Experimental",', '    "Hip Hop---Instrumental",', '    "Electronic---Vaporwave",', '    "Electronic---Ambient",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Industrial",', '    "Electronic---Industrial",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Industrial",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Industrial",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Rock---Hardcore",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Industrial",', '    "Electronic---Power Electronics",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Industrial",', '    "Electronic---Experimental",', '    "Electronic---Power Electronics",', '    "Electronic---Industrial",', '    "Electronic---Power Electronics",', '    "Electronic---Vaporwave",', '    "Electronic---Dark Ambient",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Industrial",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Power Electronics",', '    "Electronic---Vaporwave",', '    "Rock---Doom Metal",', '    "Electronic---Industrial",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Electronic---Experimental",', '    "Brass & Military---Military",', '    "Electronic---Vaporwave",', '    "Electronic---Vaporwave",', '    "Electronic---Experimental",', '    "Electronic---Power Electronics",', '    "Electronic-- ...

# %%
data_list[0]
# Out:
# ['audio_path',
#  'bpm',
#  'music_styles',
#  'voice',
#  'instrumental',
#  'danceability',
#  'arousal',
#  'valence',
#  'predominant music style']
